# %%
import pandas as pd
import numpy as np

# %%
# Linhas adicionadas na Tabela 02
# linhas_adicionadas = df_tabela02.difference(df_tabela01)

# %%
v001_df = pd.read_csv('EXP diferença de tabelas V001.csv')
v002_df = pd.read_csv('EXP diferença de tabelas V002.csv')
v003_df = pd.read_csv('EXP diferença de tabelas V003.csv')
v004_df = pd.read_csv('EXP diferença de tabelas V004.csv')

# display(v001_df)
# display(v002_df)

# %%
# linhas adicionadas em V002

# linhas_adic = v002_df.diff(v001_df)
# display(linhas_adic)

# modificacoes  = v001_df.compare(v004_df)
# display(modificacoes)

display(v001_df)
display(v004_df)
display(v003_df)
display(v002_df)
# Out:
#    Sala  Disciplina  Dia da Semana Hora de Início Hora de Término  \
# 0   101  Matemática  Segunda-feira          07:00           08:00
# 1   202   Português  Segunda-feira          08:00           09:00
# 2   101    História    Terça-feira          07:00           08:00
# 3   202    Ciências    Terça-feira          08:00           09:00
# 4   101      Inglês   Quarta-feira          07:00           08:00
#
#         Professor
# 0       Ana Silva
# 1      João Souza
# 2  Pedro Oliveira
# 3   Maria Cardoso
# 4  Roberto Mendes
#    Sala  Disciplina  Dia da Semana Hora de Início Hora de Término  \
# 0   101  Matemática  Segunda-feira          07:00           08:00
# 1   202   Português  Segunda-feira          08:00           09:00
# 2   202    Ciências    Terça-feira          08:00           09:00
# 3   101      Inglês   Quarta-feira          07:00           08:00
#
#         Professor
# 0       Ana Silva
# 1      João Souza
# 2   Maria Bardoso
# 3  Roberto Mendes
# ...
